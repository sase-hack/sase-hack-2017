# %%
# Pandas: Data Analysis Toolkit: https://pandas.pydata.org/pandas-docs/stable/10min.html
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# Seaborn: Statistical Visualization Package: https://seaborn.pydata.org/
import seaborn as sns
import numpy as np

# %%
# keeps visualizations in line
# %matplotlib inline

# %%
# read nutrition data
data = pd.read_csv("../data/nutrition.csv")

# %%
# view data (48772 rows x 33 columns)
data
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 0           2011     2011           AL      Alabama
# 1           2011     2011           AL      Alabama
# 2           2011     2011           AL      Alabama
# 3           2011     2011           AL      Alabama
# 4           2011     2011           AL      Alabama
# 5           2011     2011           AL      Alabama
# 6           2011     2011           AL      Alabama
# 7           2011     2011           AL      Alabama
# 8           2011     2011           AL      Alabama
# 9           2011     2011           AL      Alabama
# 10          2011     2011           AL      Alabama
# 11          2011     2011           AL      Alabama
# 12          2011     2011           AL      Alabama
# 13          2011     2011           AL      Alabama
# 14          2011     2011           AL      Alabama
# 15          2011     2011           AL      Alabama
# 16          2011     2011           AL      Alabama
# ...

# %%
# generate descriptive statistics
data.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  48772.000000  48772.000000              0.0  44169.000000
# mean    2013.023948   2013.023948              NaN     31.280174
# std        1.540284      1.540284              NaN     10.425274
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2011.000000   2011.000000              NaN     24.000000
# 50%     2013.000000   2013.000000              NaN     30.700000
# 75%     2015.000000   2015.000000              NaN     37.200000
# max     2015.000000   2015.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    44169.000000          44169.000000            44169.000000
# mean        31.280174             27.012149               36.114042
# std         10.425274             10.209319               11.380409
# min          0.900000              0.300000                3.000000
# ...

# %%
# sorting by columns
data.sort_values(by='Question')
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 48771       2015     2015           PR     Puerto Rico
# 7359        2014     2014           GA         Georgia
# 7360        2014     2014           GA         Georgia
# 7361        2014     2014           GA         Georgia
# 7362        2014     2014           GA         Georgia
# 7363        2014     2014           GA         Georgia
# 7364        2014     2014           GA         Georgia
# 7358        2014     2014           GA         Georgia
# 7365        2014     2014           GA         Georgia
# 7367        2014     2014           GA         Georgia
# 7368        2014     2014           GA         Georgia
# 7369        2014     2014           GA         Georgia
# 7370        2014     2014           GA         Georgia
# 7371        2014     2014           GA         Georgia
# 7372        2014     2014           GA         Georgia
# 7366        2014     2014           GA         Georgia
# ...
